# %%
from utilities_nlp_pkg.text_preprocessor import TextPreprocessor as tp

# %%
tp.get_ngrams('дом', max_len=6)
# Out:
# {'до', 'дом', 'ом'}

# %%
corpus = ['такие системы нашли широкое применение образовании', 
'известно такие информационные системы направлены главным образом решение практических учебных задач возникающих слабо структурированных трудно формализуемых предметных областях образовании', 
'основу концепции интеллектуальности положено умение работать формализованными знаниями человека', 
'проблема поиска прогрессивных математических методов анализа проектирования образовательных сложных систем постоянно актуальна',
'наблюдается повышенный интерес разработкам области экспертных систем учебного назначения широких слоев специалистов разных профилей числе преподавателей', 
'отмечается интерес распределенным интеллектуальным системам сетевом обучении четкого понимания эффективно организовать образовательный процесс получения желаемого результата', 
'построении педагогических образовательных моделей сетевой информационной образовательной среде',
'теоретико педагогический аспект эффективности применения сетевом обучении требует новых способов приемов организации совместной учебной деятельности сетевом взаимодействии учащихся преподавателей', 
'основных свойств интерактивного обучения открытая форма информационного обмена внешней средой числе доступ знаниям профессиональных педагогов экспертов которые имеют личный работы сетевыми технологиями способны прогнозировать развитие технологий',
'знания недостаточно структурированы такая предметная область нуждается экспертной системе', 
'возникают проблемы связанные многие исследователи области технологий сетевого обучения переносят традиционные педагогические методики сетевое обучение учета специфики', 
'традиционные лекции учебник малоэффективны сетевом обучении специфика сетевого обучения подразумевает организованный направленный открытый доступ динамичным системам постоянно актуализуемой информации доступные онлайн консультации новые методические подходы организации совместной проектной деятельности другое',
'технология сетевого обучения многих случаях предполагает возможность выбора учащимся собственного расписания темпа ритма обучения', 
'возрастает нагрузка сетевых преподавателей модераторов тьюторов', 
'индивидуализация снижение данной рутинной нагрузки невозможны использования подсистем', 
'подсистемы могли обеспечить развитую автоматизированную систему интеллектуальных подсказок помощи онлайн консультаций сетевого обучения использовании разных образовательных методов обучения лекций практикумов проектной деятельности конференций деловых интерактивных тренингов',
'уникальные вопросы адресуются непосредственно преподавателю эксперту',
'анализ применения информационных систем автоматизации учебного процесса образовательных учреждениях выявил противоречий нарушающих основных тенденции современного образования дифференциацию интеграцию показал отсутствие целенаправленного использования управления учебным процессом соответствии требуемыми принципами дидактических систем', 
'настоящего времени остается актуальным выявление основных противоречий управлении процессом обучения определение средств решения основе использования современных информационных технологий первую очередь экспертных систем',
'устранению указанных противоречий может служить введение учебный процесс подсистемы осуществляющей процесс обучения адаптивного блока интеллектуальной поддержки процесса обучения интеллектуализацию информационной системы целом', 
'путем создания интеллектуальных подсистем модулей позволяющих проводить обучение аттестацию анализировать эффективность обучения основе тестов созданных экспертами индивидуализировать процесс обучения']

# %% [markdown]
# Необходимо определиться с тем, что делать со словами, которые перевести в начальную форму не представляется возможным (слова-trash). Варианты:
# 1. Выкидывать на этапе предобработки
# 1. Выбрасывать на этапе формирования таблицы слово-контекст
# 1. Оставлять как метку (*TRASH*)
# 1. Оставлять без изменений
# 1. Добавлять к словам доп.метку
